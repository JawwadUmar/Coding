# %% [markdown]
# #### Stock Data Analysis
#
# Time Series data is a series of data points indexed in time order. Time series data is everywhere, so manipulating them is important for any data analyst or data scientist.
#
# In this notebook, you will discover and explore data from the stock market, particularly some technology stocks (Apple, Amazon, Google, and Microsoft). you need to visualize different aspects of it using Seaborn and Matplotlib. you will look at a few ways of analyzing the risk of a stock, based on its previous performance history. you will also be predicting future stock prices through any time series prediction model!

# %% [markdown]
# #### Getting the Data
# Install the dependencies as required and load the dataset usign pandas , you might need to parse the date time as well
#
# Understand the data:
# Volume is the amount of an asset or security that changes hands over some period of time, often over the course of a day. For instance, the stock trading volume would refer to the number of shares of security traded between its daily open and close. Trading volume, and changes to volume over the course of time, are important inputs for technical traders.
#
# The data set contains data from 2014 to 2017 of S & P 500. The Standard and Poor's 500, or simply the S&P 500, is a stock market index tracking the performance of 500 large companies listed on stock exchanges in the United States. It is one of the most commonly followed equity indices. As of December 31, 2020, more than $5.4 trillion was invested in assets tied to the performance of the index. There are 505 unique values i.e. 505 total stocks that are listed on United States stock market.
#
#
# The closing price is the last price at which the stock is traded during the regular trading day. A stock’s closing price is the standard benchmark used by investors to track its performance over time.
#
# The opening price is the price at which the first trade is executed at the beginning of a trading session or time period. It represents the starting point for price movement during that particular period.
#
# High (H): The highest price reached during the specified time period.
#
# Low (L): The lowest price reached during the specified time period.
#
# Close (C): The closing price is the last price at which a trade occurs before the end of

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import os
stock_data = pd.read_csv("https://raw.githubusercontent.com/Alfred-hq/data_science_task/master/stock_prices.csv", parse_dates=['date'])

# %%
stock_data.tail(8)
# Out:
#        symbol       date    open    high     low   close   volume
# 497464    XOM 2017-12-29   84.00   84.20   83.64   83.64  8523411
# 497465   XRAY 2017-12-29   66.30   66.72   65.77   65.83   917075
# 497466    XRX 2017-12-29   29.40   29.47   29.12   29.15  1537390
# 497467    XYL 2017-12-29   68.53   68.80   67.92   68.20  1046677
# 497468    YUM 2017-12-29   82.64   82.71   81.59   81.61  1347613
# 497469    ZBH 2017-12-29  121.75  121.95  120.62  120.67  1023624
# 497470   ZION 2017-12-29   51.28   51.55   50.81   50.83  1261916
# 497471    ZTS 2017-12-29   72.55   72.76   72.04   72.04  1704122

# %%
stock_data.dtypes
# Out:
# symbol            object
# date      datetime64[ns]
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int64
# dtype: object

# %%
stock_data.isnull().sum()
# Out:
# symbol     0
# date       0
# open      11
# high       8
# low        8
# close      0
# volume     0
# dtype: int64

# %% [markdown]
# ### 1. There are a few missing values in the open, high and low columns (all float64). Can you replace the missing values with their respective means ?

# %%
# stock_data['open'] = stock_data['open'].fillna(float(stock_data['open'].mean()), inplace=True)
# stock_data['open'].mean()
stock_data['open'] = stock_data['open'].fillna(stock_data['open'].mean())
stock_data['high'] = stock_data['high'].fillna(stock_data['high'].mean())
stock_data['low'] = stock_data['low'].fillna(stock_data['low'].mean())

# %% [markdown]
# #### 2. Calculate the % growth of stocks from  2014 to 2016 ?

# %%
# write your code here

# %% [markdown]
# #### 3. Which date in the sample saw the lowest overall trading volume? On that date, which two stocks were traded least?

# %%
stock_data.loc[stock_data['volume'] == stock_data['volume'].min()]
# Out:
#        symbol       date       open       high        low  close  volume
# 249223    DHR 2016-01-12  86.352275  87.132562  85.552467  88.55       0
# 249438      O 2016-01-12  86.352275  87.132562  85.552467  52.43       0
# 278801     UA 2016-04-07  86.352275  87.132562  85.552467  41.56       0
# 308365    FTV 2016-07-01  86.352275  87.132562  85.552467  49.54       0

# %% [markdown]
# #### 4. On which date did Apple (AAPL) see the most volatility, measured by the difference between the high and low price?

# %%
# stock_data['volatility'] = stock_data['high'] - stock_data['low']
apple_data = stock_data.loc[stock_data['symbol'] == "AAPL"]
apple_data['date'].loc[apple_data['volatility'] == apple_data['volatility'].max()]
# Out:
# 201209   2015-08-24
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# #### 5. If you could go back in time and invest in one stock from 1/2/2014 - 12/29/2016, which stock do you this is the most risky?

# %%
# stock_data['date'] = pd.to_datetime(stock_data['date'], format='%d/%m/%Y')
df = stock_data.loc[stock_data['date'] <= '2016-12-29']
df[['symbol', 'open', 'close', 'volatility']].groupby(['symbol']).agg(['mean']).max()
# Out:
# open        mean    1254.745046
# close       mean    1254.571788
# volatility  mean      25.236748
# dtype: float64

# %% [markdown]
# ### 6. What was the correlation between different stocks opening prices ? could you plot the relationship ?

# %%
stock_data.plot(x='date',y='open')
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# #### 7. What was the daily return of the stock on average? Could you plot the average return for each company?

# %%
# write your code here

# %% [markdown]
# #### 8. How much value do we put at risk by investing in a particular stock?
#
# There are many ways we can quantify risk, one of the most basic ways using the information we've gathered on daily percentage returns is by comparing the expected return with the standard deviation of the daily returns.
#
# Hint:First calculate the expected returns using standard deviation and then try to calculate the risk

# %%
# write you code here

# %% [markdown]
# #### 9. Predicting the closing price stock price of APPLE inc: (BONUS)
#
# You only need to explain the approach you would follow inorder to design a price predictor model on this dataset

# %%
# write you code here
